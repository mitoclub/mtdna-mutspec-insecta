# %%
from pymutspec import draw
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

PATH_TO_MUTSPEC = '/home/gabs/Documents/lab/TermitesAndCockroaches/mtdna-mutstep-insecta/data/NemuPipeline/AllInsects/midori_all_insects_mutspec/ms12syn_clusters_iqtree.tsv'
PATH_TO_MUTSPEC_INTER = '/home/gabs/Documents/lab/TermitesAndCockroaches/mtdna-mutstep-insecta/data/NemuPipeline/AllInsects/midori_all_insects_mutspec/ms12syn_internal_clusters_iqtree.tsv'

# %%
mutspec12 = pd.read_csv(PATH_TO_MUTSPEC, sep='\t')
mutspec12_inter = pd.read_csv(PATH_TO_MUTSPEC_INTER, sep='\t')

# %%
for cluster in mutspec12.Cluster.unique():
    draw.plot_mutspec12(mutspec12[mutspec12.Cluster == cluster], title=f'Mutational spectrum of cluster {int(cluster)} ')

# %%
for cluster in mutspec12_inter.Cluster.unique():
    draw.plot_mutspec12(mutspec12_inter[mutspec12_inter.Cluster == cluster], title=f'Mutational spectrum of cluster {int(cluster)} ')
