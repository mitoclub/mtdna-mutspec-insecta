# %%
from pymutspec import draw
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

PATH_TO_MUTSPEC = '/home/gabs/Documents/lab/TermitesAndCockroaches/MutSpec-Redone/results/Dolphin/midori_all_insects_mutspecs/mutspec12AddedClusters.tsv'

# %%
mutspec12 = pd.read_csv(PATH_TO_MUTSPEC, sep='\t', index_col=0)
mutspec12 = mutspec12.rename(columns={'MutSpec12inter' : 'MutSpec'}) # renaming column names to fit plotting scripts, because I'm an idiot

# %%
for cluster in mutspec12.Cluster.unique():
    draw.plot_mutspec12(mutspec12[mutspec12.Cluster == cluster], title=f'Mutational spectrum of cluster {int(cluster)} ')
